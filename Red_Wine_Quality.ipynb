# %% [markdown]
# <a href="https://colab.research.google.com/github/ArpanChaudhary/ML_Project/blob/main/Red_Wine_Quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Red Wine.csv')

df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,15))
plotnumber=1

for column in df:
  if plotnumber <= 12:
    ax = plt.subplot(4,3,plotnumber)
    sns.distplot(df[column])
    plt.xlabel(column,fontsize=15)
  plotnumber+=1

plt.show()

# %%
plt.figure(figsize=(20,15))
plotnumber=1

for column in df:
  if plotnumber <= 12:
    ax = plt.subplot(4,3,plotnumber)
    plt.boxplot(df[column])
    plt.xlabel(column,fontsize=15)
  plotnumber+=1

plt.show()

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df = df.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity','citric acid':'citric_acid','residual sugar':'residual_sugar',
                        'free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'})

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)

iqr = q3 - q1

# %%
fix_acmax = (q3.fixed_acidity + (1.5 * iqr.fixed_acidity))

fix_acmax
# Out:
# 12.349999999999998

# %%
index = np.where(df['fixed_acidity'] > fix_acmax)

index
# Out:
# (array([ 205,  206,  243,  244,  264,  294,  328,  338,  339,  347,  353,
#          359,  363,  364,  366,  374,  381,  391,  394,  409,  429,  440,
#          442,  446,  470,  472,  509,  510,  516,  538,  544,  548,  554,
#          555,  557,  559,  560,  564,  565,  596,  599,  601,  603,  611,
#          652,  680,  811,  814, 1224]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1550, 12)

# %%
fix_acmin = (q1.fixed_acidity - (1.5 * iqr.fixed_acidity))

fix_acmin
# Out:
# 3.95

# %%
index = np.where(df['fixed_acidity'] < fix_acmin)
index
# Out:
# (array([], dtype=int64),)

# %%
vol_acidmax = (q3.volatile_acidity + (1.5 * iqr.volatile_acidity))

vol_acidmax
# Out:
# 1.0150000000000001

# %%
index = np.where(df['volatile_acidity'] > vol_acidmax)
index
# Out:
# (array([  38,   94,  120,  126,  127,  134,  199,  521,  627,  644,  654,
#          659,  664,  678,  851, 1212, 1250, 1263, 1418]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1531, 12)

# %%
vol_acidmin = (q1.volatile_acidity - (1.5 * iqr.volatile_acidity))

vol_acidmin
# Out:
# 0.015000000000000013

# %%
index = np.where(df['volatile_acidity'] < vol_acidmin)
index
# Out:
# (array([], dtype=int64),)

# %%
citric_max = (q3.citric_acid + (.15 * iqr.citric_acid))

citric_max
# Out:
# 0.4695

# %%
index = np.where(df['citric_acid'] > citric_max)

index
# Out:
# (array([   3,   16,   19,   20,   46,   55,   60,   67,   73,   74,   75,
#           80,   81,   83,  104,  106,  107,  125,  139,  144,  145,  159,
#          175,  179,  180,  191,  193,  194,  200,  201,  203,  206,  217,
#          232,  241,  247,  248,  253,  257,  259,  260,  265,  269,  274,
#          277,  279,  288,  291,  292,  297,  313,  314,  316,  317,  321,
#          324,  325,  326,  327,  328,  338,  339,  340,  343,  344,  345,
#          346,  347,  350,  352,  353,  354,  355,  367,  368,  369,  371,
#          372,  376,  377,  380,  381,  382,  386,  389,  391,  396,  402,
#          404,  405,  406,  407,  409,  410,  412,  413,  418,  419,  420,
#          422,  424,  427,  428,  429,  431,  432,  433,  437,  440,  441,
#          444,  448,  449,  450,  451,  455,  458,  459,  462,  465,  468,
#          469,  470,  472,  474,  477,  478,  479,  480,  481,  482,  483,
#          484,  485,  486,  487,  488,  490,  491,  492,  495,  496,  502,
# ...

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1258, 12)

# %%
citric_min = (q1.citric_acid -(1.5 * iqr.citric_acid))

citric_min
# Out:
# -0.4049999999999999

# %%
index = np.where(df['citric_acid'] < citric_min)

index
# Out:
# (array([], dtype=int64),)

# %%
resi_max = (q3.residual_sugar + (1.5 * iqr.residual_sugar))

resi_max
# Out:
# 3.6500000000000004

# %%
index = np.where(df['residual_sugar'] > resi_max)

index
# Out:
# (array([   8,   10,   13,   14,   16,   29,   31,   34,   35,   49,   50,
#           56,   57,  127,  128,  129,  130,  136,  137,  161,  219,  221,
#          222,  224,  225,  228,  261,  262,  294,  296,  304,  336,  343,
#          376,  383,  393,  394,  413,  417,  423,  471,  490,  546,  619,
#          625,  630,  643,  644,  650,  652,  656,  662,  699,  753,  759,
#          764,  776,  783,  786,  792,  797,  798,  834,  839,  848,  873,
#          883,  899,  917,  926,  930,  935,  948,  964,  975,  976,  982,
#          983,  993, 1015, 1041, 1053, 1068, 1074, 1086, 1092, 1101, 1112,
#         1113, 1115, 1119, 1123, 1147, 1151, 1170, 1180, 1181, 1205, 1216,
#         1222, 1237, 1249]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1156, 12)

# %%
resi_min = (q1.residual_sugar - (1.5 * iqr.residual_sugar))

resi_min
# Out:
# 0.8499999999999996

# %%
index = np.where(df['residual_sugar'] < resi_min)

index
# Out:
# (array([], dtype=int64),)

# %%
chloride_max = (q3.chlorides +(1.5 * iqr.chlorides))

chloride_max
# Out:
# 0.11999999999999998

# %%
index = np.where(df['chlorides'] > chloride_max)

index
# Out:
# (array([  11,   28,   56,   92,  109,  122,  178,  217,  219,  220,  289,
#          334,  335,  352,  369,  389,  478,  479,  481,  482,  485,  499,
#          500,  511,  533,  534,  579,  605,  634,  684,  738,  749,  783,
#          820,  822,  871,  876,  877,  938,  972, 1025]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1115, 12)

# %%
chloride_min = (q1.chlorides - (1.5 * iqr.chlorides))

chloride_min
# Out:
# 0.04000000000000002

# %%
index = np.where(df['chlorides'] < chloride_min)

index
# Out:
# (array([ 393,  397,  478,  511,  512, 1092]),)

# %%
df = df.drop(df.index[index])
df.shape
# Out:
# (1109, 12)

# %%
free_max = (q3.free_sulfur_dioxide + (1.5 * iqr.free_sulfur_dioxide))

free_max
# Out:
# 42.0

# %%
index = np.where(df['free_sulfur_dioxide'] > free_max)

index
# Out:
# (array([301, 351, 384, 579, 580, 619, 693, 733, 751, 769, 804, 813, 834]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1096, 12)

# %%
free_min = (q1.free_sulfur_dioxide - (1.5 * iqr.free_sulfur_dioxide))

free_min
# Out:
# -14.0

# %%
index = np.where(df['free_sulfur_dioxide'] < free_min)

index
# Out:
# (array([], dtype=int64),)

# %%
total_max = (q3.total_sulfur_dioxide + (1.5 * iqr.total_sulfur_dioxide))

total_max
# Out:
# 122.0

# %%
index = np.where(df['total_sulfur_dioxide'] > total_max)

index
# Out:
# (array([  55,   57,   59,   60,   61,  132,  133,  134,  152,  214,  238,
#          264,  351,  352,  363,  386,  392,  413,  428,  455,  456,  470,
#          938,  939,  953, 1009, 1012, 1064, 1065, 1066]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1066, 12)

# %%
total_min = (q1.total_sulfur_dioxide - (1.5 * iqr.total_sulfur_dioxide))

total_min
# Out:
# -38.0

# %%
index = np.where(df['total_sulfur_dioxide'] < total_min)

index
# Out:
# (array([], dtype=int64),)

# %%
density_max = (q3.density + (1.5 * iqr.density))

density_max
# Out:
# 1.0011875

# %%
index = np.where(df['density'] > density_max)

index
# Out:
# (array([], dtype=int64),)

# %%
density_min = (q1.density - (1.5 * iqr.density))

density_min
# Out:
# 0.9922475000000001

# %%
index = np.where(df['density'] < density_min)

index
# Out:
# (array([ 96,  98, 315, 470, 607, 624, 625, 695, 699, 777, 806, 807, 829,
#         972, 973]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1051, 12)

# %%
ph_max = (q3.pH + (1.5 * iqr.pH))

ph_max
# Out:
# 3.6849999999999996

# %%
index = np.where(df['pH'] > ph_max)

index
# Out:
# (array([ 29,  58, 180, 182, 553, 557, 600, 601, 678, 817, 831, 835, 882,
#         965, 967]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1036, 12)

# %%
ph_min = (q1.pH - (1.5 * iqr.pH))

ph_min
# Out:
# 2.925

# %%
index = np.where(df['pH'] < ph_min)

index
# Out:
# (array([341, 343, 944]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1033, 12)

# %%
sulphates_max = (q3.sulphates + (1.5 * iqr.sulphates))

sulphates_max
# Out:
# 0.9999999999999999

# %%
index = np.where(df['sulphates'] > sulphates_max)

index
# Out:
# (array([ 10,  27,  51, 103, 285, 286, 332, 486, 703, 863, 889, 893]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1021, 12)

# %%
sulphates_min = (q1.sulphates - (1.5 * iqr.sulphates))

sulphates_min
# Out:
# 0.28000000000000014

# %%
index = np.where(df['sulphates'] < sulphates_min)

index
# Out:
# (array([], dtype=int64),)

# %%
alcohol_max = (q3.alcohol + (1.5 * iqr.alcohol))

alcohol_max
# Out:
# 13.5

# %%
index = np.where(df['alcohol'] > alcohol_max)

index
# Out:
# (array([265, 676]),)

# %%
df = df.drop(df.index[index])

df.shape
# Out:
# (1019, 12)

# %%
alcohol_min = (q1.alcohol - (1.5 * iqr.alcohol))

alcohol_min
# Out:
# 7.1000000000000005

# %%
index = np.where(df['alcohol'] < alcohol_min)

index
# Out:
# (array([], dtype=int64),)

# %%
plt.figure(figsize=(20,15))
plotnumber=1

for column in df:
  if plotnumber <= 12:
    ax = plt.subplot(4,3,plotnumber)
    plt.boxplot(df[column])
    plt.xlabel(column,fontsize=15)
  plotnumber+=1

plt.show()

# %%
corr = df.corr().abs()

plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)

plt.show()

# %%
x = df.drop(columns='quality')

y = df['quality']

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25)

# %%
lr = LogisticRegression()

lr.fit(x_train,y_train)

lr_pred = lr.predict(x_test)

accuracy = accuracy_score(y_test,lr_pred)

accuracy
# Out:
# 0.6196078431372549

# %%
confusion_matrix(y_test,lr_pred)
# Out:
# array([[ 1,  6,  0,  0,  0],
#        [ 1, 89, 34,  2,  0],
#        [ 0, 37, 59,  4,  0],
#        [ 0,  2,  9,  9,  0],
#        [ 0,  0,  1,  1,  0]])

# %%
print(classification_report(y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.50      0.14      0.22         7
#            5       0.66      0.71      0.68       126
#            6       0.57      0.59      0.58       100
#            7       0.56      0.45      0.50        20
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.62       255
#    macro avg       0.46      0.38      0.40       255
# weighted avg       0.61      0.62      0.61       255

# %%
knn = KNeighborsClassifier()

knn.fit(x_train,y_train)

knn_pred = knn.predict(x_test)

accuracy = accuracy_score(y_test,knn_pred)

accuracy
# Out:
# 0.6235294117647059

# %%
confusion_matrix(y_test,knn_pred)
# Out:
# array([[ 1,  5,  1,  0,  0],
#        [ 4, 87, 33,  2,  0],
#        [ 0, 30, 64,  6,  0],
#        [ 0,  1, 12,  7,  0],
#        [ 0,  0,  0,  2,  0]])

# %%
print(classification_report(y_test,knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.20      0.14      0.17         7
#            5       0.71      0.69      0.70       126
#            6       0.58      0.64      0.61       100
#            7       0.41      0.35      0.38        20
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.62       255
#    macro avg       0.38      0.36      0.37       255
# weighted avg       0.62      0.62      0.62       255

# %%
dt = DecisionTreeClassifier()

dt.fit(x_train,y_train)

dt_pred = dt.predict(x_test)

accuracy = accuracy_score(y_test,dt_pred)

accuracy
# Out:
# 0.6470588235294118

# %%
confusion_matrix(y_test,dt_pred)
# Out:
# array([[ 1,  5,  1,  0,  0],
#        [ 4, 91, 31,  0,  0],
#        [ 4, 26, 62,  7,  1],
#        [ 0,  5,  4, 11,  0],
#        [ 0,  0,  0,  2,  0]])

# %%
print(classification_report(y_test,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.11      0.14      0.12         7
#            5       0.72      0.72      0.72       126
#            6       0.63      0.62      0.63       100
#            7       0.55      0.55      0.55        20
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.65       255
#    macro avg       0.40      0.41      0.40       255
# weighted avg       0.65      0.65      0.65       255

# %%
rf = RandomForestClassifier()

rf.fit(x_train,y_train)

rf_pred = lr.predict(x_test)

accuracy = accuracy_score(y_test,rf_pred)

accuracy
# Out:
# 0.6196078431372549

# %%
confusion_matrix(y_test,rf_pred)
# Out:
# array([[ 1,  6,  0,  0,  0],
#        [ 1, 89, 34,  2,  0],
#        [ 0, 37, 59,  4,  0],
#        [ 0,  2,  9,  9,  0],
#        [ 0,  0,  1,  1,  0]])

# %%
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.50      0.14      0.22         7
#            5       0.66      0.71      0.68       126
#            6       0.57      0.59      0.58       100
#            7       0.56      0.45      0.50        20
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.62       255
#    macro avg       0.46      0.38      0.40       255
# weighted avg       0.61      0.62      0.61       255

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y1_train = le.fit_transform(y_train)

y1_test = le.fit_transform(y_test)

# %%
xg = XGBClassifier()

xg.fit(x_train,y1_train)

xg_pred = xg.predict(x_test)

# %%
accuracy = accuracy_score(y1_test,xg_pred)

accuracy
# Out:
# 0.12941176470588237

# %%
confusion_matrix(y1_test,xg_pred)
# Out:
# array([[ 0,  1,  5,  1,  0,  0],
#        [ 0,  2, 94, 30,  0,  0],
#        [ 0,  0, 24, 74,  2,  0],
#        [ 0,  0,  4,  5, 10,  1],
#        [ 0,  0,  0,  0,  2,  0],
#        [ 0,  0,  0,  0,  0,  0]])

# %%
print(classification_report(y1_test,xg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.67      0.02      0.03       126
#            2       0.19      0.24      0.21       100
#            3       0.05      0.25      0.08        20
#            4       0.14      1.00      0.25         2
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.13       255
#    macro avg       0.17      0.25      0.09       255
# weighted avg       0.41      0.13      0.11       255

# %%
svc = SVC()

svc.fit(x_train,y_train)

svc_pred = svc.predict(x_test)

accuracy = accuracy_score(y_test,svc_pred)

accuracy
# Out:
# 0.6627450980392157

# %%
confusion_matrix(y_test,svc_pred)
# Out:
# array([[ 0,  6,  1,  0,  0],
#        [ 0, 92, 34,  0,  0],
#        [ 0, 29, 69,  2,  0],
#        [ 0,  1, 11,  8,  0],
#        [ 0,  0,  1,  1,  0]])

# %%
print(classification_report(y_test,svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.72      0.73      0.72       126
#            6       0.59      0.69      0.64       100
#            7       0.73      0.40      0.52        20
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.66       255
#    macro avg       0.41      0.36      0.38       255
# weighted avg       0.65      0.66      0.65       255

# %%
# import pickle

# pickle.dump(dt,open('dt_redwine_classifier','wb'))
